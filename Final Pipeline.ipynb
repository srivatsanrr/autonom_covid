# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.externals import joblib
from sklearn import preprocessing
import pandas as pd
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier as rf
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import make_pipeline
import json
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# Json with UID:'high'

# %%
# Data Pipeline
def data_preprocessor(path):
    # Reading data from file
    dat=pd.read_excel(path)
    
    # remove unnecessary cols
    names=dat['Name'].values
    dat=dat.drop(["Name","Insurance", "salary", "people_ID"],  axis=1)
    # Label Encoding
    dat["Region"] = dat["Region"].astype('category').cat.codes
    dat["Gender"] = dat["Gender"].astype('category').cat.codes
    dat["Designation"] = dat["Designation"].astype('category').cat.codes
    dat["Married"] = dat["Married"].astype('category').cat.codes
    dat["Mode_transport"] = dat["Mode_transport"].astype('category').cat.codes
    dat["Occupation"] = dat["Occupation"].astype('category').cat.codes
    dat["Married"] = dat["Married"].astype('category').cat.codes
    dat["comorbidity"] = dat["comorbidity"].astype('category').cat.codes
    dat["Pulmonary score"] = dat["Pulmonary score"].astype('category').cat.codes
    dat["cardiological pressure"] = dat["cardiological pressure"].astype('category').cat.codes
    
        # Missing value handling using mean and forward fill methods
    dat['Children']=dat['Children'].fillna(int(np.mean(dat['Children'])))
    dat['Diuresis']=dat['Diuresis'].fillna(int(np.mean(dat['Diuresis'])))
    dat['d-dimer']=dat['d-dimer'].fillna(int(np.mean(dat['d-dimer'])))
    dat['Heart rate']=dat['Heart rate'].fillna(int(np.mean(dat['Heart rate'])))
    dat['Platelets']=dat['Platelets'].fillna(int(np.mean(dat['Platelets'])))
    dat['HDL cholesterol']=dat['HDL cholesterol'].fillna(int(np.mean(dat['HDL cholesterol'])))
    dat['HBB']=dat['HBB'].fillna(int(np.mean(dat['HBB'])))
    dat['FT/month']=dat['FT/month'].fillna(int(np.mean(dat['FT/month'])))
    dat['comorbidity'].fillna('ffill', inplace=True)
    dat['cardiological pressure'].fillna('ffill', inplace=True)
    
    # (x-mu / sigma) scaling
    sclr = preprocessing.StandardScaler()
    x_scaled = sclr.fit_transform(dat.values)
    dat = pd.DataFrame(x_scaled)
    
    # PCA
    ncomp=6
    pca_cov = PCA(n_components=ncomp)
    principalComponents = pca_cov.fit_transform(dat.values)
    principaldf=pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2','pc3','pc4','pc5','pc6'])
    X=principaldf.values
    # For single sample inference
    if(X.shape[0]==1):
        X=X.reshape(1,-1)
    return([X, names])

# %%
def inference(X,names, model='model_sar.pkl'): 
    clf = joblib.load(model)
    y=clf.predict(X)
    values = ['High', 'Low', 'Mid']
    y_labels= [values[i] for i in y]
    ret= json.dumps(dict(zip(names,y_labels)))
    return(ret)

# %%
def main(path, model_path):
    (X,names)=data_preprocessor(path)
    return inference(X,names, model_path)

# %%
main('dataset/Test_dataset.xlsx', model_path='autonom_covid/autonom_covid/model_sar.pkl')
# Out:
# '{"smt rekha prajapat": "Mid", "nirmal": "Mid", "pinky": "Mid", "pooja @aafrin": "Mid", "anjali": "Mid", "diwan chand": "Mid", "sunita": "Mid", "gaytri": "Mid", "ritu": "Mid", "poonam": "Mid", "harprit": "Mid", "aamir hussain": "Mid", "ramesh": "Mid", "dinkar sharma": "Mid", "mahak": "Mid", "raju": "Mid", "dinesh": "Mid", "najimuddin": "Mid", "vikrant @ vicky": "Mid", "vikas kumar": "Mid", "rakesh kumar": "Mid", "jawed ahmad": "Mid", "priti": "Mid", "arthi": "Mid", "sandeep kumar": "Mid", "uma @ reena": "Mid", "mala": "Mid", "ram lal": "Mid", "soniya": "Mid", "ganesh": "Mid", "vijay": "Mid", "bharat": "Mid", "nagma": "Mid", "abhishek  sharma": "Mid", "sarthak dadwal": "Mid", "punni devi": "Mid", "pinki": "Mid", "ram suresh @ babloo": "Mid", "jamila khatun": "Mid", "chotu": "Mid", "madhan singh": "Mid", "meena": "Mid", "manju": "Mid", "lakhmi chand": "Mid", "shiwani": "Mid", "rehaan": "Mid", "arun kol": "Mid", "deepanker": "Mid", "sonu": "Mid", "vikash": "Mid", "aamin": "Mid", "ravinder prakash": "Mid", "akif mohammad": "Mid", "laxmi devi": "Mid", "muskan": "Mid", "mumtaj ahmad": "Mid", "sama": "Mid", "deepak kumar": "Mid", "gruchran singh": "Mid", "ghan shyam": "Mid", "monika": "Mid", "chura bahadur": "Mid", "manoj patra": "Mid", "ganga devi": "Mid", "rampal jain": "Mid", "santosh kumar": "Mid", "mamta paliwal": "Mid", "yashoda": "Mid", "kashish": "Mid", "lakshay": "Mid", "arti arora": "Mid", "doli": "Mid", "kanhiya sukla": "Mid", "jyoti": "Mid", "asha": "Mid", "anita nagesia": "Mid", "kalu": "Mid", "randhir ram": "Mid", "mohan singh": "Mid", "rahul": "Mid", "rony rao": "Mid", "manoj kumar": "Mid", "kalyan": "Mid", "manav": "Mid", "shanta meena": "Mid", "gopal": "Mid", "simmi": "Mid", "baljeet": "Mid", "seema @ simran": "Mid", "manjiv singh": "Mid", "mahbir parsad": "Mid", "shivam s/o": "Mid", "shaboob": "Mid", "sapna": "Mid", "neeraj sharma": "Mid", "vandana": "Mid", "ashwani @ arjun": "Mid", "pooja": "Mid", "kamna": "Mid", "bhawana": "Mid", "neelam": "Mid", "amarjeet": "Mid", "phooli devi": "Mid", "gopal dhakad": "Mid", "satpal": "Mid", "gaurav gupta": "Mid", "anash": "Mid", "pari mohmad": "Mid", "aditya @ vishnu": "Mid", "amrit patel": "Mid", "afsana": "Mid", "urvarshi": "Mid", "sultan singh": "Mid", "hina": "Mid", "jitendra yadav": "Mid", "durgabai": "Mid", "tarnnum": "Mid", "manoj": "Mid", "smt. seema": "Mid", "kulli devi": "Mid", "rubi": "Mid", "laxmi": "Mid", "sangeeta devi": "Mid", "hari prasad": "Mid", "rekha": "Mid", "vishal": "Mid", "rajwanti": "Mid", "kumkum": "Mid", "priya": "Mid", "vipin pandey": "Mid", "amrta kumari": "Mid", "sher khan": "Mid", "raj bala @ bharati": "Mid", "rashid hussain": "Mid", "poshetty gajjala": "Mid", "naeem khan": "Mid", "arati": "Mid", "faqir chand": "Mid", "waheeda": "Mid", "dhmendar": "Mid", "ankit": "Mid", "talib": "Mid", "aarti": "Mid", "rajni": "Mid", "sonu@akil": "Mid", "sachin kumar": "Mid", "kushal": "Mid", "aamir": "Mid", "shiv kumar": "Mid", "smt. shakuntla devi": "Mid", "nisha": "Mid", "sumit": "Mid", "lada bai  marubhat": "Mid", "vijay kumar": "Mid", "sagar": "Mid", "karishama": "Mid", "ashwani @ ashu": "Mid", "durgesh suman": "Mid", "raju lal": "Mid", "kamlesh": "Mid", "mahesh": "Mid", "sunita bai": "Mid", "deepa": "Mid", "khimanand": "Mid", "santosh devi": "Mid", "mohit lakra": "Mid", "arvind": "Mid", "rajesh kumar": "Mid", "anju devi": "Mid", "azmira": "Mid", "sashi": "Mid", "kumari arti": "Mid", "atul verma": "Mid", "neeraj singh": "Mid", "kamal panwar": "Mid", "priyanka": "Mid", "mehboob alam": "Mid", "rinki": "Mid", "gori": "Mid", "ravi chandra natarajan": "Mid", "smt. kanya devi": "Mid", "ravi": "Mid", "nitin kumar": "Mid", "shabina": "Mid", "jiyaul": "Mid", "gyarsi": "Mid", "pankajsheel": "Mid", "ram dulare": "Mid", "smt. santosh with her four children": "Mid", "kajol": "Mid", "umar": "Mid", "ravinder": "Mid", "sunita devi": "Mid", "vinod kumar @ vinnu": "Mid", "jawahar singh": "Mid", "chander kala": "Mid", "nazahat": "Mid", "nand kishore": "Mid", "tripti @ neeraj": " ...
